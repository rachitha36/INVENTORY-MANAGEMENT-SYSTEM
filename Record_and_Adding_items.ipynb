# %%
record = { 1001 : { "name" : "Apples" , "quantity" : 30 , "price" : 100 , "category" : "fruits" , "mgf" : "2/2/2022"},
	   1002 : { "name" : "Mango" , "quantity" : 30 , "price" : 50 , "category" : "fruits" , "mgf" : "2/2/2022"},
	   1003 : { "name" : "Grapes" , "quantity" : 30 , "price" : 80 , "category" : "fruits" , "mgf" : "2/2/2022"},
	   1004 : { "name" : "Bananas" , "quantity" : 30 , "price" : 30 , "category" : "fruits" , "mgf" : "2/2/2022"},
	   1005 : { "name" : "Orange" , "quantity" : 30 , "price" : 120 , "category" : "fruits" , "mgf" : "2/2/2022"},
	   1006 : { "name" : "Amul cheese" , "quantity" : 30 , "price" : 730 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1007 : { "name" : "Amul milk" , "quantity" : 40 , "price" : 50 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1008 : { "name" : "Amul butter" , "quantity" : 50 , "price" : 450 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1009 : { "name" : "Amul fresh cream" , "quantity" : 50 , "price" : 240 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1010 : { "name" : "Nandini milk" , "quantity" : 50 , "price" : 40 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1011 : { "name" : "Nandini ghee" , "quantity" : 35 , "price" : 500 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1012 : { "name" : "Nandini cheese" , "quantity" : 30 , "price" : 700 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1013 : { "name" : "Amul vanilla ice cream" , "quantity" : 40 , "price" : 500 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1014 : { "name" : "Amul fruit n nut" , "quantity" : 30 , "price" : 500 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1015 : { "name" : "Amul tutti frutti" , "quantity" : 30 , "price" : 575 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1016 : { "name" : "Cornetto creame brulee" , "quantity" : 50 , "price" : 240 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1017 : { "name" : "Cornetto kesar pistha" , "quantity" : 35 , "price" : 180 , "category" : "dairy" , "mgf" : "2/2/2022"},
	   1018 : { "name" : "Licious chicken tangdi" , "quantity" : 40 , "price" : 500 , "category" : "meat" , "mgf" : "2/2/2022"},
	   1019 : { "name" : "Licious chicken breast" , "quantity" : 30 , "price" : 570 , "category" : "meat" , "mgf" : "2/2/2022"},
	   1020 : { "name" : "Licious chicken drumstick" , "quantity" : 40 , "price" : 470 , "category" : "meat" , "mgf" : "2/2/2022"},
	   1021 : { "name" : "Licious vanjaram" , "quantity" : 20 , "price" : 1000 , "category" : "meat" , "mgf" : "2/2/2022"},
	   1022 : { "name" : "Licious prawns" , "quantity" : 50 , "price" : 550 , "category" : "meat" , "mgf" : "2/2/2022"},
	   1023 : { "name" : "Licious goat mutton" , "quantity" : 80 , "price" : 800 , "category" : "meat" , "mgf" : "2/2/2022"},
	   1024 : { "name" : "Licious goat keema" , "quantity" : 30 , "price" : 580 , "category" : "meat" , "mgf" : "2/2/2022"},
	   1025 : { "name" : "Licious lamb keema" , "quantity" : 50 , "price" : 575 , "category" : "meat" , "mgf" : "2/2/2022"},
	   1026 : { "name" : "Dairy milk silk" , "quantity" : 50 , "price" : 100 , "category" : "chocolates" , "mgf" : "2/2/2022"},
	   1027 : { "name" : "Snickers" , "quantity" : 50 , "price" : 35 , "category" : "chocolates" , "mgf" : "2/2/2022"},
	   1028 : { "name" : "Milky bar" , "quantity" : 75 , "price" : 50 , "category" : "chocolates" , "mgf" : "2/2/2022"},
	   1029 : { "name" : "5 star" , "quantity" : 60 , "price" : 170 , "category" : "chocolates" , "mgf" : "2/2/2022"},
	   1030 : { "name" : "Kitkat" , "quantity" : 70 , "price" : 130 , "category" : "chocolates" , "mgf" : "2/2/2022"},
	   1031 : { "name" : "Moong dal" , "quantity" : 50 , "price" : 140 , "category" : "pulses" , "mgf" : "2/2/2022"},
	   1032 : { "name" : "Urad dal" , "quantity" : 60 , "price" : 150 , "category" : "pulses" , "mgf" : "2/2/2022"},
	   1033 : { "name" : "Rajma(red)" , "quantity" : 50 , "price" : 160 , "category" : "pulses" , "mgf" : "2/2/2022"},
	   1034 : { "name" : "Rajma(light)" , "quantity" : 50 , "price" : 170 , "category" : "pulses" , "mgf" : "2/2/2022"},
	   1035 : { "name" : "Chana dal" , "quantity" : 50 , "price" : 180 , "category" : "pulses" , "mgf" : "2/2/2022"},
	   1036 : { "name" : "Chick peas" , "quantity" : 50 , "price" : 240 , "category" : "pulses" , "mgf" : "2/2/2022"},
	   1037 : { "name" : "Green peas" , "quantity" : 50 , "price" : 360 , "category" : "pulses" , "mgf" : "2/2/2022"},
	   1038 : { "name" : "Yellow peas" , "quantity" : 50 , "price" : 320 , "category" : "pulses" , "mgf" : "2/2/2022"},
	   1039 : { "name" : "Moth" , "quantity" : 50 , "price" : 140 , "category" : "pulses" , "mgf" : "2/2/2022"},
	   1040 : { "name" : "India gate Basmathi rice" , "quantity" : 50 , "price" : 70 , "category" : "rice" , "mgf" : "2/2/2022"},
	   1041 : { "name" : "Bullet sona masori" , "quantity" : 50 , "price" : 40 , "category" : "rice" , "mgf" : "2/2/2022"},
	   1042 : { "name" : "Freedom sunflower oil" , "quantity" : 50 , "price" : 166 , "category" : "oils" , "mgf" : "2/2/2022"},
	   1043 : { "name" : "Sundrop oil heart" , "quantity" : 50 , "price" : 192 , "category" : "oils" , "mgf" : "2/2/2022"},
	   1044 : { "name" : "Sundrop superlite" , "quantity" : 50 , "price" : 215 , "category" : "oils" , "mgf" : "2/2/2022"},
	   1045 : { "name" : "Sundrop oil heart 5l" , "quantity" : 50 , "price" : 962 , "category" : "oils" , "mgf" : "2/2/2022"},
	   1046 : { "name" : "Fortune sunlite sunflower 5l" , "quantity" : 50 , "price" : 776 , "category" : "oils" , "mgf" : "2/2/2022"},
	   1047 : { "name" : "Fortune soyabean oil" , "quantity" : 50 , "price" : 105 , "category" : "oils" , "mgf" : "2/2/2022"},
	   1048 : { "name" : "Fortune groundnut oil 5l" , "quantity" : 50 , "price" : 829 , "category" : "oils" , "mgf" : "2/2/2022"},
 	   1049 : { "name" : "Fortune xpert pro imunity blended" , "quantity" : 50 , "price" : 808 , "category" : "oils" , "mgf" : "2/2/2022"},
	   1050 : { "name" : "soffala gold" , "quantity" : 20 , "price" : 200 , "category" : "oils" , "mgf" : "2/2/2022"}}

# %% [markdown]
# **Add new item to inventory**

# %%
p_id = str(input("enter the product id:"))
name = str(input("enter name of the product:"))
qty = int(input("enter the quantity available:"))
price = int(input("enter the price of product:"))
category = str(input("enter the category of the product:"))
mfg = str(input("enter the manufactured date:"))

record[p_id] = { "name" : name , "quantity" : qty , "price" : price , "category" : category , "mfg" : mfg }
js = json.dumps(record)




fd = open("record.json","w")

fd.write(js)


fd.close()
# Out:
# enter the product id:1071
# enter name of the product:MUTTON
# enter the quantity available:70
# enter the price of product:300
# enter the category of the product:MEAT
# enter the manufactured date:2/2/2001

# %%
record
# Out:
# {1001: {'category': 'fruits',
#   'mgf': '2/2/2022',
#   'name': 'Apples',
#   'price': 100,
#   'quantity': 30},
#  1002: {'category': 'fruits',
#   'mgf': '2/2/2022',
#   'name': 'Mango',
#   'price': 50,
#   'quantity': 30},
#  1003: {'category': 'fruits',
#   'mgf': '2/2/2022',
#   'name': 'Grapes',
#   'price': 80,
#   'quantity': 30},
#  1004: {'category': 'fruits',
#   'mgf': '2/2/2022',
#   'name': 'Bananas',
#   'price': 30,
#   'quantity': 30},
#  1005: {'category': 'fruits',
#   'mgf': '2/2/2022',
#   'name': 'Orange',
#   'price': 120,
#   'quantity': 30},
#  1006: {'category': 'dairy',
#   'mgf': '2/2/2022',
#   'name': 'Amul cheese',
#   'price': 730,
#   'quantity': 30},
#  1007: {'category': 'dairy',
#   'mgf': '2/2/2022',
#   'name': 'Amul milk',
#   'price': 50,
#   'quantity': 40},
#  1008: {'category': 'dairy',
#   'mgf': '2/2/2022',
#   'name': 'Amul butter',
#   'price': 450,
#   'quantity': 50},
#  1009: {'category': 'dairy',
#   'mgf': '2/2/2022',
# ...
